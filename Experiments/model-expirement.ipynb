# %%
import sqlite3, json, warnings
import pandas as pd
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer_350M = AutoTokenizer.from_pretrained("../models/nsql-350M")
model_350M = AutoModelForCausalLM.from_pretrained("../models/nsql-350M")

# tokenizer_2B = AutoTokenizer.from_pretrained("../models/nsql-2B")
# model_2B = AutoModelForCausalLM.from_pretrained("../models/nsql-2B")

# %%
with open("../src/spider/table_database_map.json") as f:
    table_map_db = json.load(f)

# %%
df = pd.read_csv('../src/NSText2SQL/train_spider.csv')
df.head()
# Out:
#                                             Question  \
# 0  What are the first names, office locations of ...
# 1  Please show the songs that have result 'nomina...
# 2          Which teams had more than 3 eliminations?
# 3  Show the names of people, and dates and venues...
# 4  Tell me the the date when the first claim was ...
#
#                                                Table  \
# 0  CREATE TABLE course (\n    crs_code text,\n   ...
# 1  CREATE TABLE artist (\n    artist_id number,\n...
# 2  CREATE TABLE elimination (\n    elimination_id...
# 3  CREATE TABLE people (\n    people_id number,\n...
# 4  CREATE TABLE settlements (\n    settlement_id ...
#
#                                                  SQL
# 0  SELECT T2.emp_fname, T4.prof_office, T3.crs_de...
# 1  SELECT T2.song FROM music_festival AS T1 JOIN ...
# 2  SELECT team FROM elimination GROUP BY team HAV...
# 3  SELECT T3.name, T2.date, T2.venue FROM debate_...
# 4  SELECT date_claim_made FROM claims ORDER BY da...

# %%
def table_column_of_create_table(query):
    lines = query.splitlines()
    columns = []
    table_names = []

    # Look for "CREATE TABLE" and start capturing columns
    capture = False
    for line in lines:
        if "CREATE TABLE" in line:
            capture = True
            table_names.append(line.split()[-2].lower())
        elif line.strip().endswith(')') or line.strip().endswith(');'):
            capture = False
        elif capture:
            column_name = line.strip().split()[0]
            if column_name in ["CONSTRAINT", "PRIMARY"]: continue
            columns.append(column_name)
    return table_names, columns

# %%
def create_prompt(question, schema):
    full_prompt = ""
    full_prompt += f"{str(schema)}\n\n"
    full_prompt += "-- Using valid SQLite, answer the following questions for the tables provided above.\n\n"
    full_prompt += f"--{question}\n\nSELECT"
    return full_prompt

# %%
def pred_sql(prompt, model_name):

    if model_name == "nsql-350M":
        input_ids = tokenizer_350M(prompt, return_tensors="pt").input_ids
        generated_ids = model_350M.generate(input_ids, max_length=500)
        return tokenizer_350M.decode(generated_ids[0], skip_special_tokens=True).split('\n')[-1]
    # elif model_name == "nsql-2B":
    #     input_ids = tokenizer_2B(prompt, return_tensors="pt").input_ids
    #     generated_ids = model_2B.generate(input_ids, max_length=500)
    #     return tokenizer_2B.decode(generated_ids[0], skip_special_tokens=True).split('\n')[-1]

# %% [markdown]
# ## Query by SQL

# %%
def query_db(sql_query, db_name):
    try:
        conn = sqlite3.connect(f'../src/spider/database/{db_name}/{db_name}.sqlite')
        cursor = conn.cursor()
    except:
        return "CANNOT CONNECT DATABASE"
    try:
        cursor.execute(sql_query)
        results = cursor.fetchall()
    except:
        return "CANNOT FETCHING DATA"
    conn.close()
    return results

# %%
df.shape

# %%
# expect_query_results = []
# nsql350M_query_results = []
# nsql350M_query = []
# nsql2B_query_results = []
# nsql2B_query = []

# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     for i, row in df.iterrows():
#         question = row['Question']
#         print(question)
#         schema = row['Table']
#         expect_query = row['SQL']
#         schema_tables = table_column_of_create_table(schema)[0]
#         try:
#             db_of_table = table_map_db[schema_tables[0].lower()]
#         except KeyError:
#             error_occur = "TABLE NOT MATCH"
#             expect_query_results.append(error_occur)
#             nsql350M_query.append(error_occur)
#             nsql350M_query_results.append(error_occur)
#             # nsql2B_query.append(error_occur)
#             # nsql2B_query_results.append(error_occur)
#             continue

#         expect_result = query_db(expect_query, db_of_table)
#         full_prompt = create_prompt(question, schema)
#         # try:
#         #     pred_sql_query_350M = pred_sql(full_prompt, "nsql-350M")
#         # except:
#         #     pred_sql_query_350M = "GEN QUERY ERROR"
#         pred_sql_query_350M = "test"
#         print(pred_sql_query_350M)
#         pred_result_350M = query_db(pred_sql_query_350M, db_of_table)
        
#         # try:
#         #     pred_sql_query_2B = pred_sql(full_prompt, "nsql-2B")
#         # except:
#         #     pred_sql_query_2B = "GEN QUERY ERROR"
#         # print(pred_sql_query_2B)
#         # pred_result_2B = query_db(pred_sql_query_2B, db_of_table)

#         expect_query_results.append(expect_result)
#         nsql350M_query.append(pred_sql_query_350M)
#         nsql350M_query_results.append(pred_result_350M)
#         # nsql2B_query.append(pred_sql_query_2B)
#         # nsql2B_query_results.append(pred_result_2B)
#         print(i)

# %%
# df['nsql-350M-query'] = nsql350M_query
# # df['nsql-2B-query'] = nsql2B_query
# df['expect_result'] = expect_query_results
# df['nsql-350M-result'] = nsql350M_query_results
# # df['nsql-2B-result'] = nsql2B_query_results

# df.to_csv("model-expirements.csv", index=False)
# df.head()

# %%
df = pd.read_csv("../src/temp-model-expirements.csv")
exclude_values = ["CANNOT FETCHING DATA", "TABLE NOT MATCH", None]
filtered_df = df[~df['Expect-result'].isin(exclude_values)]
print(filtered_df.shape)
filtered_df.head()

# %%
filtered_df.to_excel("model-exp.xlsx", index=False)

# %% [markdown]
# ## Predict SQL result by unseen spider dataset

# %%
seen_questions = df['Question'].to_list()
print("SPIDER for training",df.shape)
df.head()

# %%
from datasets import load_dataset

dataset = load_dataset("spider")
spider_df = pd.concat([pd.DataFrame(dataset['train']), pd.DataFrame(dataset['validation'])], ignore_index=True)[['question','query' ,'db_id']]
print(spider_df.shape)
spider_df.head()

# %%
unseen_df = spider_df[~spider_df['question'].isin(seen_questions)]
unseen_df = unseen_df.reset_index(drop=True)
unseen_df.shape

# %%
unseen_df.head()

# %%
import os

folder_path = "../src/spider/database"

db = dict()

if os.path.exists(folder_path) and os.path.isdir(folder_path):
    files = os.listdir(folder_path)
    for db_id in files:
        db_path = os.path.join(folder_path, db_id)
        sqlite_db = [os.path.join(db_path, sql) for sql in os.listdir(db_path) if ".sqlite" in sql]
        assert len(sqlite_db) == 1
        db[db_id] = sqlite_db[0]

# %%
def get_schema(sqlite_db_path):
    connection = sqlite3.connect(sqlite_db_path)
    cursor = connection.cursor()

    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    full_sql = ""
    for table in tables:
        table_name = table[0]
        cursor.execute(f"PRAGMA table_info({table_name});")
        columns = cursor.fetchall()

        sql = f"CREATE TABLE {table_name} ("
        for column in columns:
            column_name = column[1]
            column_datatype = column[2].lower()
            sql += f"{column_name} {column_datatype}, "
        sql = sql[:-2] + ");"
        full_sql += sql
    
    cursor.close()
    connection.close()
    return full_sql

# %%
# for db_id, database_path in db.items():
#     print(get_schema(database_path))
#     # exists_table.append(table)
#     print('---------------------------------')

# %%
questions = []
expect_querys = []
expect_query_results = []
nsql350M_query_results = []
nsql350M_query = []
nsql2B_query_results = []
nsql2B_query = []
predict_result = []

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for i, row in unseen_df.iterrows():
        question = row['question']
        schema = get_schema(db[row['db_id']])
        expect_query = row['query']
        print("EXPECT QUERY\n", expect_query)
        expect_result = query_db(expect_query, row['db_id'])
        full_prompt = create_prompt(question, schema)
        try:
            pred_sql_query_350M = pred_sql(full_prompt, "nsql-350M")
        except:
            pred_sql_query_350M = "GEN QUERY ERROR"
        print("NSQL-350M QUERY\n", pred_sql_query_350M)
        pred_result_350M = query_db(pred_sql_query_350M, row['db_id'])
        
        try:
            pred_sql_query_2B = pred_sql(full_prompt, "nsql-2B")
        except:
            pred_sql_query_2B = "GEN QUERY ERROR"
        print("NSQL-2B QUERY\n", pred_sql_query_2B)
        pred_result_2B = query_db(pred_sql_query_2B, row['db_id'])

        questions.append(question)
        expect_querys.append(expect_query)
        expect_query_results.append(expect_result)
        nsql350M_query.append(pred_sql_query_350M)
        nsql350M_query_results.append(pred_result_350M)
        nsql2B_query.append(pred_sql_query_2B)
        nsql2B_query_results.append(pred_result_2B)
        print(f"COMPLETE {i} FROM {unseen_df.shape[0]}")
        print()
        if i > 5: 
            data = {
                "Question": questions,
                "Expect-query": expect_querys,
                "NSQL-350M-query": nsql350M_query,
                "NSQL-2B-query": nsql2B_query,
                "Expect-result": expect_query_results,
                "NSQL-350M-result": nsql350M_query_results,
                "NSQL-2B-result": nsql2B_query_results
            }
            temp_df = pd.DataFrame(data)
            temp_df.to_csv("temp-model-expirements.csv", index=False)
            print("******** WRITED TEMP DATAFRAME ********")
            print()
            break
        if not i % 100:
            data = {
                "Question": questions,
                "Expect-query": expect_querys,
                "NSQL-350M-query": nsql350M_query,
                "NSQL-2B-query": nsql2B_query,
                "Expect-result": expect_query_results,
                "NSQL-350M-result": nsql350M_query_results,
                "NSQL-2B-result": nsql2B_query_results
            }
            temp_df = pd.DataFrame(data)
            temp_df.to_csv("temp-model-expirements.csv", index=False)
            print("******** WRITED TEMP DATAFRAME ********")
            print()

# %%
df['nsql-350M-query'] = nsql350M_query
df['nsql-2B-query'] = nsql2B_query
df['expect_result'] = expect_query_results
df['nsql-350M-result'] = nsql350M_query_results
df['nsql-2B-result'] = nsql2B_query_results

df.to_csv("model-unseen-expirements.csv", index=False)
df.head()

# %% [markdown]
# ## PointX Keymatrix

# %%
import sqlparse, json
import pandas as pd

# %%
with open("../src/pointx/schemas/pointx_keymatrix_dly_columns_type.json") as f:
    pointx_keymatrix_schema = json.load(f)

pointx_keymatrix_columns = list(pointx_keymatrix_schema.keys())[1:]
pointx_keymatrix_columns[:5]
# Out:
# ['month_id',
#  'ntx_pointx_financial',
#  'ntx_pointx_financial_out',
#  'ncust_user',
#  'ncust_pointx']

# %%
sql_extract_token_type = {
            sqlparse.sql.IdentifierList, sqlparse.sql.Where,
            sqlparse.sql.Having, sqlparse.sql.Comparison, sqlparse.sql.Function,
            sqlparse.sql.Parenthesis, sqlparse.sql.Operation, sqlparse.sql.Case
        }

def columns_from_query(sql_query:str, all_columns:list):
    # identifiers contain table name and column name
    if type(sql_query) == str:
        sql_query = sqlparse.parse(sql_query)[0]
    columns = []
    for token in sql_query:
        if isinstance(token, sqlparse.sql.Identifier) and token.get_real_name().lower() in all_columns:
            columns.append(token.get_real_name().lower())
        elif hasattr(token, "tokens"):
            columns.extend(columns_from_query(token.tokens, all_columns))
    return list(set(columns))

# %%
def query_pointx_db(sql_query):
    try:
        conn = sqlite3.connect(f'../src/pointx/database/pointx.db')
        cursor = conn.cursor()
    except:
        return "CANNOT CONNECT DATABASE"
    try:
        cursor.execute(sql_query)
        results = cursor.fetchall()
    except:
        return "CANNOT FETCHING DATA"
    conn.close()
    return results

# %%
pointx_keymatrix_pair = pd.read_excel("../src/pointx/PointX - NLQ training data set.xlsx", sheet_name="pointx_keymatrix")[['NLQ', 'NLQ with helper', 'SQL']].iloc[:39]
pointx_keymatrix_pair.head()
# Out:
#                                                  NLQ  \
# 0  What is the total number of all financial tran...
# 1  What is the total amount of points generated b...
# 2  What is the total amount of points generated b...
# 3  What is the average rate of released points fo...
# 4  Can you determine the average number of custom...
#
#                                      NLQ with helper  \
# 0  What is the total number of ntx_pointx_financi...
# 1  What is the total amount of amt_point_topup in...
# 2  What is the total amount of amt_point_pay for ...
# 3       What is the average rate_point_per_baht_pay?
# 4  Can you determine the average number of ncust_...
#
#                                                  SQL
# 0  SELECT month_id, SUM(ntx_pointx_financial) FRO...
# 1  SELECT SUM(amt_point_topup) FROM pointx_keymat...
# 2  SELECT month_id, SUM(amt_point_pay) FROM point...
# 3  SELECT AVG(rate_point_per_baht_pay) FROM point...
# 4  SELECT month_id, AVG(ncust_visit) FROM pointx_...

# %% [markdown]
# ### Experiment of NSQL with F1 100%

# %%
def create_pointx_keymatrix_schema(list_cols:list):
    prompt = "CREATE TABLE pointx_keymatrix_dly ("
    for col in list_cols:
        prompt += f"{col} {pointx_keymatrix_schema[col]},"
    return prompt[:-1] + ")"

# %%
experiment_result = { 'Question' : [],
                      'Question with helper' : [],
                      'Expect SQL': [],
                      'Predict SQL': [],
                      'Predict SQL with helper': [],
                      'Expect result': [],
                      'Predict result': [],
                      'Predict result with helper': [],
    
}
for i, row in pointx_keymatrix_pair.iterrows():
    
    question = row['NLQ']
    question_helper = row['NLQ with helper']
    used_cols = columns_from_query(row['SQL'], pointx_keymatrix_columns)
    schema_prompt = create_pointx_keymatrix_schema(used_cols)
    full_prompt = create_prompt(question, schema_prompt)
    result = pred_sql(full_prompt, 'nsql-350M')

    full_prompt_helper = create_prompt(question_helper, schema_prompt)
    result_helper = pred_sql(full_prompt_helper, 'nsql-350M')

    experiment_result['Question'].append(question)
    experiment_result['Question with helper'].append(question_helper)
    experiment_result['Expect SQL'].append(row['SQL'])
    experiment_result['Predict SQL'].append(result)
    experiment_result['Predict SQL with helper'].append(result_helper)
    
    experiment_result['Expect result'].append(query_pointx_db(row['SQL']))
    experiment_result['Predict result'].append(query_pointx_db(result))
    experiment_result['Predict result with helper'].append(query_pointx_db(result_helper))

    print(question)
    print(used_cols)
    print("EXPECT SQL:",row['SQL'])
    print("RESULT:", result)
    print("RESULT WITH HELPER:", result_helper)
    print()
# Out:
# What is the total number of all financial transactions for each month?
# ['ntx_pointx_financial', 'month_id']
# EXPECT SQL: SELECT month_id, SUM(ntx_pointx_financial) FROM pointx_keymatrix_dly  GROUP BY month_id;
# RESULT: SELECT COUNT(*), month_id FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total amount of points generated by all top-up transactions in August 2022?
# ['month_id', 'amt_point_topup']
# EXPECT SQL: SELECT SUM(amt_point_topup) FROM pointx_keymatrix_dly WHERE month_id = '2022-08';
# RESULT: SELECT SUM(amt_point_topup) FROM pointx_keymatrix_dly WHERE month_id = "August 2022";
# RESULT WITH HELPER: SELECT SUM(amt_point_topup) FROM pointx_keymatrix_dly WHERE month_id = "2022-08";
#
# What is the total amount of points generated by all payment transactions for each month in 2022?
# ['amt_point_pay', 'month_id']
# EXPECT SQL: SELECT month_id, SUM(amt_point_pay) FROM pointx_keymatrix_dly WHERE month_id LIKE '2022%' GROUP BY month_id;
# RESULT: SELECT SUM(amt_point_pay) FROM pointx_keymatrix_dly WHERE month_id = "2022";
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE month_id = "2022";
#
# What is the average rate of released points for all payment customers?
# ['rate_point_per_baht_pay']
# EXPECT SQL: SELECT AVG(rate_point_per_baht_pay) FROM pointx_keymatrix_dly;
# RESULT: SELECT AVG(rate_point_per_baht_pay) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT AVG(rate_point_per_baht_pay) FROM pointx_keymatrix_dly;
#
# Can you determine the average number of customers who visit and use the pointX app each month?
# ['ncust_visit', 'month_id']
# EXPECT SQL: SELECT month_id, AVG(ncust_visit) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT AVG(ncust_visit) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(*), month_id FROM pointx_keymatrix_dly GROUP BY month_id;
#
# What is the total number of transactions caused by all top-ups in 2022?
# ['n_topup_point', 'month_id']
# EXPECT SQL: SELECT SUM(n_topup_point) FROM pointx_keymatrix_dly WHERE month_id LIKE '2022%;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE month_id = "2022";
# RESULT WITH HELPER: SELECT COUNT(n_topup_point) FROM pointx_keymatrix_dly WHERE month_id = "2022";
#
# Total transactions are caused by payment of X-store.
# ['n_purchase']
# EXPECT SQL: SELECT SUM(n_purchase) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE key = 'Payment of X-Store';
# RESULT WITH HELPER: SELECT SUM(n_purchase) FROM pointx_keymatrix_dly;
#
# What is the total number of new customer registrations each month?
# ['month_id', 'ncust_register_success']
# EXPECT SQL: SELECT month_id, SUM(ncust_register_success) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(month_id) FROM pointx_keymatrix_dly;
#
# What is the average rate of points released for payment via X-Store?
# ['rate_point_per_baht_pay_sku']
# EXPECT SQL: SELECT AVG(rate_point_per_baht_pay_sku) FROM pointx_keymatrix_dly;
# RESULT: SELECT AVG(rate_point_per_baht_pay_sku) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT AVG(rate_point_per_baht_pay_sku) FROM pointx_keymatrix_dly;
#
# What is the total point topups occurred via manual in 2022-08?
# ['month_id', 'n_topup_point_onetime']
# EXPECT SQL: SELECT SUM(n_topup_point_onetime) FROM pointx_keymatrix_dly WHERE month_id = '2022-08';
# RESULT: SELECT SUM(n_topup_point_onetime) FROM pointx_keymatrix_dly WHERE month_id = "2022-08";
# RESULT WITH HELPER: SELECT SUM(n_topup_point_onetime) FROM pointx_keymatrix_dly WHERE month_id = "2022-08";
#
# What is the total number of points transferred to other users via an external partner?
# ['amt_point_transfer_out_extnl']
# EXPECT SQL: SELECT SUM(amt_point_transfer_out_extnl) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE amt_point_transfer_out_extnl > 0;
# RESULT WITH HELPER: SELECT COUNT(amt_point_transfer_out_extnl) FROM pointx_keymatrix_dly;
#
# Can you provide the monthly breakdown of top-up points for Cardx customers?
# ['amt_point_topup_auto_cardx', 'month_id']
# EXPECT SQL: SELECT month_id, amt_point_topup_auto_cardx FROM pointx_keymatrix_dly;
# RESULT: SELECT DISTINCT T1.month_id FROM pointx_keymatrix_dly AS T1 JOIN customer_point_topup AS T2 ON T1.month_id = T2.month_id WHERE T2.cardx_customer_id = 1;
# RESULT WITH HELPER: SELECT month_id FROM pointx_keymatrix_dly GROUP BY month_id;
#
# Can you break down the total monthly top-up points for Cardx customers?
# ['amt_point_topup_auto_cardx', 'month_id']
# EXPECT SQL: SELECT month_id, SUM(amt_point_topup_auto_cardx) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT SUM(T1.amt_point_topup_auto_cardx) FROM pointx_keymatrix_dly AS T1 JOIN customer_pointx_keymatrix AS T2 ON T1.month_id = T2.month_id WHERE T2.customer_key = 'Cardx';
# RESULT WITH HELPER: SELECT month_id FROM pointx_keymatrix_dly GROUP BY month_id;
#
# What is the total number of Point X customers coming to use the app each day?
# ['_date', 'ncust_pointx']
# EXPECT SQL: SELECT _date, SUM(ncust_pointx) FROM pointx_keymatrix_dly GROUP BY _date;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(ncust_pointx) FROM pointx_keymatrix_dly;
#
# What is the monthly average rate of points released for payment via Paywise?
# ['month_id', 'rate_point_per_baht_pay_pyw']
# EXPECT SQL: SELECT month_id, AVG(rate_point_per_baht_pay_pyw) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT AVG(rate_point_per_baht_pay_pyw) FROM pointx_keymatrix_dly WHERE month_id = "Paywise";
# RESULT WITH HELPER: SELECT AVG(rate_point_per_baht_pay_pyw) FROM pointx_keymatrix_dly;
#
# What is the total transactions are caused by payment via the Robinhood Platform each month?
# ['month_id', 'n_purchase_pyw_rbh']
# EXPECT SQL: SELECT month_id, SUM(n_purchase_pyw_rbh) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(month_id) FROM pointx_keymatrix_dly;
#
# What is the total number of transactions caused by manual top-ups on 11th August 2022?
# ['_date', 'n_topup_point_onetime']
# EXPECT SQL: SELECT SUM(n_topup_point_onetime) FROM pointx_keymatrix_dly WHERE _date = '2022-08-11';
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE _date = "11th August 2022";
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE _date = "2022-08-11";
#
# What is the total number of guest customers that came to use the Point X app on Sep 12th 2022?
# ['_date', 'ncust_guest_visit']
# EXPECT SQL: SELECT ncust_guest_visit FROM pointx_keymatrix_dly WHERE _date = '2022-07-12';
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE _date = "Sep 12, 2022";
# RESULT WITH HELPER: SELECT COUNT(ncust_guest_visit) FROM pointx_keymatrix_dly WHERE _date = "2022-07-12";
#
# How many transactions are caused by payment method using Point Only each month?
# ['month_id', 'n_point_payment_p_only']
# EXPECT SQL: SELECT month_id, SUM(n_point_payment_p_only) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(month_id) FROM pointx_keymatrix_dly;
#
# What is the monthly total number of transactions caused by payment?
# ['n_purchase', 'month_id']
# EXPECT SQL: SELECT month_id, SUM(n_purchase) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the average rate of points released for all payment customers?
# ['rate_point_per_baht_pay_weight']
# EXPECT SQL: SELECT AVG(rate_point_per_baht_pay_weight) FROM pointx_keymatrix_dly;
# RESULT: SELECT AVG(rate_point_per_baht_pay_weight) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT AVG(rate_point_per_baht_pay_weight) FROM pointx_keymatrix_dly;
#
# How many transactions are caused by payment via X-Store with Transaction Type QR 30?
# ['n_purchase_qr_30']
# EXPECT SQL: SELECT SUM(n_purchase_qr_30) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE type = "QR 30" AND payment_via = "X-Store";
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total number of Point X customers using the app on 2022-08-12?
# ['_date', 'ncust_pointx_visit']
# EXPECT SQL: SELECT ncust_pointx_visit FROM pointx_keymatrix_dly WHERE _date = '2022-08-12';
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE ncust_pointx_visit = '2022-08-12';
# RESULT WITH HELPER: SELECT COUNT(ncust_pointx_visit) FROM pointx_keymatrix_dly WHERE _date = "2022-08-12";
#
# What is the monthly total number of transactions caused by payment via Paywise?
# ['month_id', 'n_purchase_pyw']
# EXPECT SQL: SELECT month_id, SUM(n_purchase_pyw) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE month_id = "Paywise";
# RESULT WITH HELPER: SELECT COUNT(n_purchase_pyw) FROM pointx_keymatrix_dly;
#
# What is the total number of transactions transferred to other users via an external partner?
# ['n_transfer_point_out_extnl']
# EXPECT SQL: SELECT SUM(n_transfer_point_out_extnl) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE n_transfer_point_out_extnl > 0;
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total number of transactions caused by payment via Robinhood Platform?
# ['n_purchase_pyw_rbh']
# EXPECT SQL: SELECT SUM(n_purchase_pyw_rbh) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE key = 'Payment via Robinhood Platform';
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total number of transactions caused by topups via Cardx customers?
# ['n_topup_point_auto_cardx']
# EXPECT SQL: SELECT SUM(n_topup_point_auto_cardx) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE n_topup_point_auto_cardx > 0;
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# How many transactions are caused by topups onboard each day?
# ['_date', 'n_topup_point_onboard']
# EXPECT SQL: SELECT _date, SUM(n_topup_point_onboard) FROM pointx_keymatrix_dly GROUP BY _date;
# RESULT: SELECT COUNT(*), _date FROM pointx_keymatrix_dly GROUP BY _date;
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total number of Point X customers using the app via an external partner on Aug 2022?
# ['month_id']
# EXPECT SQL: SELECT  ncust_pointx_financial_out FROM pointx_keymatrix_dly WHERE month_id = '2022-08';
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE external_partner = "app" AND month_id = "2022-08";
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE month_id = "2022-08" AND financial_out = "Y";
#
# What is the monthly total number of transactions caused by payment via Scan & Pay with Transaction Type QRCS?
# ['month_id', 'n_purchase_qr_cs']
# EXPECT SQL: SELECT month_id, SUM(n_purchase_qr_cs) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE month_id = "QR" AND transaction_type = "Payment";
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total number of new customers registered from partner companies each day?
# ['mtd1_ncust_partner_new', '_date']
# EXPECT SQL: SELECT _date, SUM(mtd1_ncust_partner_new) FROM pointx_keymatrix_dly GROUP BY _date;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the total number of transactions caused by payment via Paywise?
# ['n_purchase_pyw']
# EXPECT SQL: SELECT SUM(n_purchase_pyw) FROM pointx_keymatrix_dly;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE key = 'Paywise';
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly;
#
# What is the average rate of points released for payment customers via X-Store?
# ['rate_point_per_baht_pay_sku_weight']
# EXPECT SQL: SELECT AVG(rate_point_per_baht_pay_sku_weight) FROM pointx_keymatrix_dly;
# RESULT: SELECT AVG(rate_point_per_baht_pay_sku_weight) FROM pointx_keymatrix_dly WHERE key_name = "Payment Customers via X-Store";
# RESULT WITH HELPER: SELECT AVG(rate_point_per_baht_pay_sku_weight) FROM pointx_keymatrix_dly;
#
# How many customers used the Point X app and made a payment on 8th August 2022?
# ['_date', 'ncust_pointx_financial']
# EXPECT SQL: SELECT SUM(ncust_pointx_financial) FROM pointx_keymatrix_dly WHERE _date = '2022-08-08';
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE ncust_pointx_financial = "8th August 2022";
# RESULT WITH HELPER: SELECT COUNT(ncust_pointx_financial) FROM pointx_keymatrix_dly WHERE _date = "2022-08-08";
#
# What is the monthly average cost per point for payment via Paywise, weighted by point amount?
# ['rate_baht_per_point_pay_pyw_weight', 'month_id']
# EXPECT SQL: SELECT month_id, AVG(rate_baht_per_point_pay_pyw_weight) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT AVG(rate_baht_per_point_pay_pyw_weight) FROM pointx_keymatrix_dly;
# RESULT WITH HELPER: SELECT AVG(rate_baht_per_point_pay_pyw_weight) FROM pointx_keymatrix_dly;
#
# What are the top 5 transaction dates with the highest number of points caused by payment?
# ['amt_point_pay', '_date']
# EXPECT SQL: SELECT _date, amt_point_pay FROM pointx_keymatrix_dly ORDER BY amt_point_pay DESC LIMIT 5;
# RESULT: SELECT _date FROM pointx_keymatrix_dly GROUP BY _date ORDER BY COUNT(*) DESC LIMIT 5;
# RESULT WITH HELPER: SELECT _date FROM pointx_keymatrix_dly ORDER BY amt_point_pay DESC LIMIT 5;
#
# What are the top 3 dates with the highest number of new customer registrations from partner companies?
# ['mtd1_ncust_partner_new', '_date']
# EXPECT SQL: SELECT _date, mtd1_ncust_partner_new FROM pointx_keymatrix_dly ORDER BY mtd1_ncust_partner_new DESC LIMIT 3;
# RESULT: SELECT _date FROM pointx_keymatrix_dly ORDER BY COUNT(*) DESC LIMIT 3;
# RESULT WITH HELPER: SELECT _date FROM pointx_keymatrix_dly GROUP BY _date ORDER BY COUNT(mtd1_ncust_partner_new) DESC LIMIT 3;
#
# What is the total revenue generated by payment via the mobile app, grouped by month?
# ['month_id']
# EXPECT SQL: SELECT month_id, SUM(revenue_mobile_app) FROM pointx_keymatrix_dly GROUP BY month_id;
# RESULT: SELECT COUNT(*) FROM payment_via_mobile_app;
# RESULT WITH HELPER: SELECT COUNT(month_id) FROM pointx_keymatrix_dly;
#
# How many transactions were caused by payment via credit card ?
# ['n_point_payment_p_cc']
# EXPECT SQL: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE n_point_payment_p_cc > 0;
# RESULT: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE payment_type = 'Credit Card';
# RESULT WITH HELPER: SELECT COUNT(*) FROM pointx_keymatrix_dly WHERE n_point_payment_p_cc > 0;

# %%
experiment_df = pd.DataFrame(experiment_result)
experiment_df.to_excel("experiment_pointx_keymatrix_f1_100.xlsx", index=False)
experiment_df.head()
# Out:
#                                             Question  \
# 0  What is the total number of all financial tran...
# 1  What is the total amount of points generated b...
# 2  What is the total amount of points generated b...
# 3  What is the average rate of released points fo...
# 4  Can you determine the average number of custom...
#
#                                 Question with helper  \
# 0  What is the total number of ntx_pointx_financi...
# 1  What is the total amount of amt_point_topup in...
# 2  What is the total amount of amt_point_pay for ...
# 3       What is the average rate_point_per_baht_pay?
# 4  Can you determine the average number of ncust_...
#
#                                           Expect SQL  \
# 0  SELECT month_id, SUM(ntx_pointx_financial) FRO...
# 1  SELECT SUM(amt_point_topup) FROM pointx_keymat...
# 2  SELECT month_id, SUM(amt_point_pay) FROM point...
# 3  SELECT AVG(rate_point_per_baht_pay) FROM point...
# 4  SELECT month_id, AVG(ncust_visit) FROM pointx_...
#
#                                          Predict SQL  \
# 0  SELECT COUNT(*), month_id FROM pointx_keymatri...
# 1  SELECT SUM(amt_point_topup) FROM pointx_keymat...
# 2  SELECT SUM(amt_point_pay) FROM pointx_keymatri...
# 3  SELECT AVG(rate_point_per_baht_pay) FROM point...
# 4  SELECT AVG(ncust_visit) FROM pointx_keymatrix_...
#
#                              Predict SQL with helper  \
# 0         SELECT COUNT(*) FROM pointx_keymatrix_dly;
# 1  SELECT SUM(amt_point_topup) FROM pointx_keymat...
# 2  SELECT COUNT(*) FROM pointx_keymatrix_dly WHER...
# 3  SELECT AVG(rate_point_per_baht_pay) FROM point...
# 4  SELECT COUNT(*), month_id FROM pointx_keymatri...
#
#                                        Expect result  \
# 0                   [(2022-07, 447), (2022-08, 259)]
# 1                                      [(178992.0,)]
# 2           [(2022-07, 30075.0), (2022-08, 30045.0)]
# 3                            [(13.825421897546896,)]
# 4  [(2022-07, 47.61290322580645), (2022-08, 55.15...
#
#                    Predict result      Predict result with helper
# 0  [(31, 2022-07), (19, 2022-08)]                         [(50,)]
# 1                       [(None,)]                   [(178992.0,)]
# 2                       [(None,)]                          [(0,)]
# 3         [(13.825421897546896,)]         [(13.825421897546896,)]
# 4                      [(50.48,)]  [(31, 2022-07), (19, 2022-08)]

# %%
print(query_pointx_db("SELECT month_id, SUM(revenue_mobile_app) FROM pointx_keymatrix_dly GROUP BY month_id;"))
# Out:
# [('2022-07',), ('2022-08',)]

# %%
query_db("SELECT * FROM shop LIMIT 3", "coffee_shop")
# Out:
# [(1, '1200 Main Street', '13', 42.0, '2010'),
#  (2, '1111 Main Street', '19', 38.0, '2008'),
#  (3, '1330 Baltimore Street', '42', 36.0, '2010')]
